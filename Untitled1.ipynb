# %%
# %run glassdoor_scraper_us.py

# %%
# %load get_data.py
import glassdoor_scraper_us as gs
import pandas as pd

path = '/Users/tehila/PycharmProjects/salary_us/chromedriver'


df = gs.get_jobs('data scientist',20, True, path, 15)
df.to_csv('glassdoor_jobs_us.csv', index = False)
# Out:
#  x out failed
# Progress: 0/20
# Job Title: Data Scientist 2
# Salary Estimate: $52K - $95K (Glassdoor est.)
# Job Description: Description
# Digital Health and Analytics within Humana is dedicated to transform members’ health experience and Humana’s services using technology and analytics. We are looking for a Data Scientist 2 who will design studies and utilize cutting-edge predictive modeling techniques, test rigorous hypotheses, and turn data and insights into actionable plans. Being part of talented team of data scientists with broad skills and applications, the Data Scientist will work cross-functionally and collabor
# Rating: 3.9
# Company Name: Humana
# 3.9
# Location: Louisville, KY
# Headquarters: -1
# Size: -1
# Founded: -1
# Type of Ownership: -1
# Industry: -1
# Sector: -1
# Revenue: -1
# Competitors: -1
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Progress: 1/20
# ---------------------------------------------------------------------------
# ...

# %%
test=pd.read_csv('test1.csv')
test.shape
# Out:
# (20, 14)

# %%
df
# Out:
#                                             Job Title  \
# 0                                    Data Scientist 2
# 1                                 Lead Data Scientist
# 2                                Data Scientist - HCI
# 3                                      Data Scientist
# 4          Senior Data Scientist , Advanced Analytics
# 5                             Research Data Scientist
# 6                               Senior Data Scientist
# 7                                      Data Scientist
# 8           Research Scientist, Computational Biology
# 9                                        Data Analyst
# 10                        ETL Developer/Data Engineer
# 11                                 Sr. Data Scientist
# 12                              Data Scientist Senior
# 13  Clinical Laboratory Scientist - HLA and Immuno...
# 14                                 FCC Data Scientist
# 15      Associate Scientist/Scientist, Cell Biologist
# ...
